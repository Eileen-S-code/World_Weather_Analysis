# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 624

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | musiri
# Processing Record 2 of Set 1 | ciudad dario
# Processing Record 3 of Set 1 | quixada
# Processing Record 4 of Set 1 | vila
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | kargil
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | tasiilaq
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | capao bonito
# Processing Record 13 of Set 1 | aswan
# Processing Record 14 of Set 1 | lavrentiya
# Processing Record 15 of Set 1 | coromandel
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | provideniya
# Processing Record 19 of Set 1 | tautira
# Processing Record 20 of Set 1 | urdzhar
# City not found. Skipping...
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | san cristobal
# Processing Record 23 of Set 1 | touros
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | lebu
# Processing Record 26 of Set 1 | carutapera
# Processing Record 27 of Set 1 | caravelas
# Processing Record 28 of Set 1 | tefe
# Processing Record 29 of Set 1 | chaparral
# Processing Record 30 of Set 1 | belyy yar
# Processing Record 31 of Set 1 | laguna
# Processing Record 32 of Set 1 | faanui
# Processing Record 33 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 1 | coahuayana
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | palana
# Processing Record 37 of Set 1 | maragogi
# Processing Record 38 of Set 1 | veraval
# Processing Record 39 of Set 1 | cherskiy
# Processing Record 40 of Set 1 | santa lucia
# Processing Record 41 of Set 1 | mitu
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | mairinque
# Processing Record 45 of Set 1 | the valley
# Processing Record 46 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 1 | merauke
# Processing Record 48 of Set 1 | bredasdorp
# Processing Record 49 of Set 1 | fortuna
# Processing Record 50 of Set 1 | coquimbo
# Processing Record 1 of Set 2 | kodiak
# Processing Record 2 of Set 2 | hamilton
# Processing Record 3 of Set 2 | cape town
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | sosnovo-ozerskoye
# Processing Record 6 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 2 | albany
# Processing Record 8 of Set 2 | hasaki
# Processing Record 9 of Set 2 | nouadhibou
# Processing Record 10 of Set 2 | cabo san lucas
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | svetlogorsk
# Processing Record 14 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 2 | santa rosa
# Processing Record 16 of Set 2 | emerald
# Processing Record 17 of Set 2 | ovalle
# Processing Record 18 of Set 2 | mar del plata
# Processing Record 19 of Set 2 | komsomolskiy
# Processing Record 20 of Set 2 | panaba
# Processing Record 21 of Set 2 | ahuimanu
# Processing Record 22 of Set 2 | nishihara
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | sitka
# Processing Record 25 of Set 2 | airai
# Processing Record 26 of Set 2 | port-gentil
# Processing Record 27 of Set 2 | portland
# Processing Record 28 of Set 2 | seoul
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | marathon
# Processing Record 31 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 2 | acarau
# Processing Record 33 of Set 2 | luanda
# Processing Record 34 of Set 2 | lompoc
# Processing Record 35 of Set 2 | lorengau
# Processing Record 36 of Set 2 | alyangula
# Processing Record 37 of Set 2 | sisimiut
# Processing Record 38 of Set 2 | russkaya polyana
# Processing Record 39 of Set 2 | monrovia
# Processing Record 40 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 2 | mahebourg
# Processing Record 42 of Set 2 | suntar
# Processing Record 43 of Set 2 | wuwei
# Processing Record 44 of Set 2 | hilo
# Processing Record 45 of Set 2 | avarua
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 2 | codrington
# Processing Record 48 of Set 2 | bilibino
# Processing Record 49 of Set 2 | dunedin
# Processing Record 50 of Set 2 | haimen
# Processing Record 1 of Set 3 | phan thiet
# Processing Record 2 of Set 3 | machico
# Processing Record 3 of Set 3 | torbay
# Processing Record 4 of Set 3 | buala
# Processing Record 5 of Set 3 | urengoy
# Processing Record 6 of Set 3 | bocos
# Processing Record 7 of Set 3 | maceio
# Processing Record 8 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 9 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 3 | marsa matruh
# Processing Record 11 of Set 3 | coihaique
# Processing Record 12 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 3 | hovd
# Processing Record 14 of Set 3 | nikolskoye
# Processing Record 15 of Set 3 | upernavik
# Processing Record 16 of Set 3 | nalut
# Processing Record 17 of Set 3 | rio branco
# Processing Record 18 of Set 3 | castro
# Processing Record 19 of Set 3 | mookane
# Processing Record 20 of Set 3 | general roca
# Processing Record 21 of Set 3 | punta arenas
# Processing Record 22 of Set 3 | vardo
# Processing Record 23 of Set 3 | jalu
# Processing Record 24 of Set 3 | rio gallegos
# Processing Record 25 of Set 3 | puerto colombia
# Processing Record 26 of Set 3 | puerto ayora
# Processing Record 27 of Set 3 | mataura
# Processing Record 28 of Set 3 | itoman
# Processing Record 29 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 30 of Set 3 | mercedes
# Processing Record 31 of Set 3 | mugur-aksy
# Processing Record 32 of Set 3 | san vicente de canete
# Processing Record 33 of Set 3 | puerto escondido
# Processing Record 34 of Set 3 | san patricio
# Processing Record 35 of Set 3 | jamestown
# Processing Record 36 of Set 3 | almunecar
# Processing Record 37 of Set 3 | surskoye
# Processing Record 38 of Set 3 | najran
# Processing Record 39 of Set 3 | georgetown
# Processing Record 40 of Set 3 | katsuura
# Processing Record 41 of Set 3 | riberalta
# Processing Record 42 of Set 3 | pevek
# Processing Record 43 of Set 3 | kirakira
# Processing Record 44 of Set 3 | marawi
# Processing Record 45 of Set 3 | san giustino
# Processing Record 46 of Set 3 | bambous virieux
# Processing Record 47 of Set 3 | oistins
# Processing Record 48 of Set 3 | koulikoro
# Processing Record 49 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 3 | ahipara
# Processing Record 1 of Set 4 | fort dodge
# Processing Record 2 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 4 | chateau-thierry
# Processing Record 4 of Set 4 | clyde river
# Processing Record 5 of Set 4 | thompson
# Processing Record 6 of Set 4 | camacha
# Processing Record 7 of Set 4 | gracac
# Processing Record 8 of Set 4 | salalah
# Processing Record 9 of Set 4 | vysokogornyy
# Processing Record 10 of Set 4 | santa cruz del sur
# Processing Record 11 of Set 4 | carberry
# Processing Record 12 of Set 4 | bagdarin
# Processing Record 13 of Set 4 | bethel
# Processing Record 14 of Set 4 | dikson
# Processing Record 15 of Set 4 | atsiki
# City not found. Skipping...
# Processing Record 16 of Set 4 | masallatah
# Processing Record 17 of Set 4 | tucuman
# Processing Record 18 of Set 4 | ibb
# Processing Record 19 of Set 4 | taltal
# Processing Record 20 of Set 4 | ponta do sol
# Processing Record 21 of Set 4 | roebourne
# Processing Record 22 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 4 | zhigansk
# Processing Record 24 of Set 4 | yellowknife
# Processing Record 25 of Set 4 | agadez
# Processing Record 26 of Set 4 | kabare
# Processing Record 27 of Set 4 | bonavista
# Processing Record 28 of Set 4 | saldanha
# Processing Record 29 of Set 4 | sinazongwe
# Processing Record 30 of Set 4 | ilebo
# Processing Record 31 of Set 4 | longyearbyen
# Processing Record 32 of Set 4 | narsaq
# Processing Record 33 of Set 4 | gorontalo
# Processing Record 34 of Set 4 | de-kastri
# Processing Record 35 of Set 4 | saskylakh
# Processing Record 36 of Set 4 | carnarvon
# Processing Record 37 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 4 | geraldton
# Processing Record 39 of Set 4 | tete
# Processing Record 40 of Set 4 | ilulissat
# Processing Record 41 of Set 4 | souillac
# Processing Record 42 of Set 4 | horsham
# Processing Record 43 of Set 4 | hibbing
# Processing Record 44 of Set 4 | kununurra
# Processing Record 45 of Set 4 | bambanglipuro
# Processing Record 46 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 4 | kalisz
# Processing Record 48 of Set 4 | ouesso
# Processing Record 49 of Set 4 | cantaura
# Processing Record 50 of Set 4 | quatre cocos
# Processing Record 1 of Set 5 | xianyang
# Processing Record 2 of Set 5 | luderitz
# Processing Record 3 of Set 5 | havelock
# Processing Record 4 of Set 5 | east london
# Processing Record 5 of Set 5 | lure
# Processing Record 6 of Set 5 | muroto
# Processing Record 7 of Set 5 | pochutla
# Processing Record 8 of Set 5 | inuvik
# Processing Record 9 of Set 5 | ascension
# Processing Record 10 of Set 5 | aklavik
# Processing Record 11 of Set 5 | chimbote
# Processing Record 12 of Set 5 | cururupu
# Processing Record 13 of Set 5 | itupiranga
# Processing Record 14 of Set 5 | deputatskiy
# Processing Record 15 of Set 5 | moche
# Processing Record 16 of Set 5 | sandane
# Processing Record 17 of Set 5 | manono
# Processing Record 18 of Set 5 | umm lajj
# Processing Record 19 of Set 5 | miyako
# Processing Record 20 of Set 5 | la paz
# Processing Record 21 of Set 5 | tuatapere
# Processing Record 22 of Set 5 | arraial do cabo
# Processing Record 23 of Set 5 | muzhi
# Processing Record 24 of Set 5 | inhambane
# Processing Record 25 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 5 | azanka
# Processing Record 27 of Set 5 | cockburn town
# Processing Record 28 of Set 5 | ribeira grande
# Processing Record 29 of Set 5 | merrill
# Processing Record 30 of Set 5 | interlaken
# Processing Record 31 of Set 5 | erenhot
# Processing Record 32 of Set 5 | college
# Processing Record 33 of Set 5 | husavik
# Processing Record 34 of Set 5 | vila franca do campo
# Processing Record 35 of Set 5 | chokurdakh
# Processing Record 36 of Set 5 | sawtell
# Processing Record 37 of Set 5 | birao
# Processing Record 38 of Set 5 | lufilufi
# Processing Record 39 of Set 5 | magaria
# Processing Record 40 of Set 5 | alice springs
# Processing Record 41 of Set 5 | tucumcari
# Processing Record 42 of Set 5 | tessalit
# Processing Record 43 of Set 5 | cutervo
# Processing Record 44 of Set 5 | coulihaut
# City not found. Skipping...
# Processing Record 45 of Set 5 | montrose
# Processing Record 46 of Set 5 | sangar
# Processing Record 47 of Set 5 | novonukutskiy
# Processing Record 48 of Set 5 | lagoa
# Processing Record 49 of Set 5 | kavaratti
# Processing Record 50 of Set 5 | clifton
# Processing Record 1 of Set 6 | nioro
# Processing Record 2 of Set 6 | muros
# Processing Record 3 of Set 6 | makakilo city
# Processing Record 4 of Set 6 | port lincoln
# Processing Record 5 of Set 6 | birin
# Processing Record 6 of Set 6 | hobart
# Processing Record 7 of Set 6 | ixtapa
# Processing Record 8 of Set 6 | pervomayskoye
# Processing Record 9 of Set 6 | tecoanapa
# Processing Record 10 of Set 6 | vostok
# Processing Record 11 of Set 6 | marrakesh
# Processing Record 12 of Set 6 | kontagora
# Processing Record 13 of Set 6 | kharod
# Processing Record 14 of Set 6 | scicli
# Processing Record 15 of Set 6 | summerville
# Processing Record 16 of Set 6 | asau
# Processing Record 17 of Set 6 | prieska
# Processing Record 18 of Set 6 | aasiaat
# Processing Record 19 of Set 6 | tigil
# Processing Record 20 of Set 6 | thunder bay
# Processing Record 21 of Set 6 | kutum
# Processing Record 22 of Set 6 | margate
# Processing Record 23 of Set 6 | bandarbeyla
# Processing Record 24 of Set 6 | mareeba
# Processing Record 25 of Set 6 | solnechnyy
# Processing Record 26 of Set 6 | necochea
# Processing Record 27 of Set 6 | kerema
# Processing Record 28 of Set 6 | saint george
# Processing Record 29 of Set 6 | kyzyl-suu
# Processing Record 30 of Set 6 | zaozerne
# Processing Record 31 of Set 6 | bengkulu
# Processing Record 32 of Set 6 | olavarria
# Processing Record 33 of Set 6 | turukhansk
# Processing Record 34 of Set 6 | batagay-alyta
# Processing Record 35 of Set 6 | vila velha
# Processing Record 36 of Set 6 | bizhbulyak
# Processing Record 37 of Set 6 | middelkerke
# Processing Record 38 of Set 6 | cap malheureux
# Processing Record 39 of Set 6 | westport
# Processing Record 40 of Set 6 | skjervoy
# Processing Record 41 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 6 | usinsk
# Processing Record 43 of Set 6 | mnogovershinnyy
# Processing Record 44 of Set 6 | rassvet
# Processing Record 45 of Set 6 | aquiraz
# Processing Record 46 of Set 6 | victoria
# Processing Record 47 of Set 6 | anadyr
# Processing Record 48 of Set 6 | voyvozh
# Processing Record 49 of Set 6 | tilichiki
# Processing Record 50 of Set 6 | omsukchan
# Processing Record 1 of Set 7 | sestri levante
# Processing Record 2 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 3 of Set 7 | chara
# Processing Record 4 of Set 7 | camopi
# Processing Record 5 of Set 7 | suoyarvi
# Processing Record 6 of Set 7 | homer
# Processing Record 7 of Set 7 | saint-philippe
# Processing Record 8 of Set 7 | straubing
# Processing Record 9 of Set 7 | am timan
# Processing Record 10 of Set 7 | oudtshoorn
# Processing Record 11 of Set 7 | fagernes
# Processing Record 12 of Set 7 | ellisras
# Processing Record 13 of Set 7 | hellin
# Processing Record 14 of Set 7 | stykkisholmur
# Processing Record 15 of Set 7 | sri aman
# Processing Record 16 of Set 7 | sao jose da coroa grande
# Processing Record 17 of Set 7 | kabalo
# Processing Record 18 of Set 7 | raudeberg
# Processing Record 19 of Set 7 | rocha
# Processing Record 20 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 7 | aykhal
# Processing Record 22 of Set 7 | iberia
# Processing Record 23 of Set 7 | beysehir
# Processing Record 24 of Set 7 | cidreira
# Processing Record 25 of Set 7 | tornio
# Processing Record 26 of Set 7 | kaura namoda
# Processing Record 27 of Set 7 | alihe
# Processing Record 28 of Set 7 | norman wells
# Processing Record 29 of Set 7 | karema
# Processing Record 30 of Set 7 | lamu
# Processing Record 31 of Set 7 | sakakah
# Processing Record 32 of Set 7 | tiksi
# Processing Record 33 of Set 7 | machhlishahr
# Processing Record 34 of Set 7 | fort beaufort
# Processing Record 35 of Set 7 | bairiki
# Processing Record 36 of Set 7 | pisco
# Processing Record 37 of Set 7 | eydhafushi
# Processing Record 38 of Set 7 | marystown
# Processing Record 39 of Set 7 | vanimo
# Processing Record 40 of Set 7 | shangzhi
# Processing Record 41 of Set 7 | toftir
# City not found. Skipping...
# Processing Record 42 of Set 7 | haines junction
# Processing Record 43 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 7 | kloulklubed
# Processing Record 45 of Set 7 | kamen-na-obi
# Processing Record 46 of Set 7 | vredendal
# Processing Record 47 of Set 7 | rundu
# Processing Record 48 of Set 7 | klaksvik
# Processing Record 49 of Set 7 | baruun-urt
# Processing Record 50 of Set 7 | shimoda
# Processing Record 1 of Set 8 | miandrivazo
# Processing Record 2 of Set 8 | guerrero negro
# Processing Record 3 of Set 8 | abu samrah
# Processing Record 4 of Set 8 | xichang
# Processing Record 5 of Set 8 | yar-sale
# Processing Record 6 of Set 8 | tocache
# Processing Record 7 of Set 8 | kuna
# Processing Record 8 of Set 8 | sibu
# Processing Record 9 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 10 of Set 8 | gallup
# Processing Record 11 of Set 8 | meulaboh
# Processing Record 12 of Set 8 | comodoro rivadavia
# Processing Record 13 of Set 8 | yining
# Processing Record 14 of Set 8 | zunyi
# Processing Record 15 of Set 8 | andenes
# Processing Record 16 of Set 8 | fairbanks
# Processing Record 17 of Set 8 | thinadhoo
# Processing Record 18 of Set 8 | sandakan
# Processing Record 19 of Set 8 | champerico
# Processing Record 20 of Set 8 | ansbach
# Processing Record 21 of Set 8 | gawler
# Processing Record 22 of Set 8 | kavieng
# Processing Record 23 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 24 of Set 8 | sao filipe
# Processing Record 25 of Set 8 | bouna
# Processing Record 26 of Set 8 | tingi
# Processing Record 27 of Set 8 | adrar
# Processing Record 28 of Set 8 | sault sainte marie
# Processing Record 29 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 30 of Set 8 | megion
# Processing Record 31 of Set 8 | syracuse
# Processing Record 32 of Set 8 | catabola
# Processing Record 33 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 34 of Set 8 | baillif
# Processing Record 35 of Set 8 | zaykovo
# Processing Record 36 of Set 8 | saint-paul-les-dax
# Processing Record 37 of Set 8 | leningradskiy
# Processing Record 38 of Set 8 | esperance
# Processing Record 39 of Set 8 | san pedro
# Processing Record 40 of Set 8 | kokstad
# Processing Record 41 of Set 8 | nyrob
# Processing Record 42 of Set 8 | goundam
# Processing Record 43 of Set 8 | berani
# Processing Record 44 of Set 8 | tolbazy
# Processing Record 45 of Set 8 | mantua
# Processing Record 46 of Set 8 | korla
# Processing Record 47 of Set 8 | atar
# Processing Record 48 of Set 8 | bailleul
# Processing Record 49 of Set 8 | te anau
# Processing Record 50 of Set 8 | balkanabat
# Processing Record 1 of Set 9 | dingle
# Processing Record 2 of Set 9 | rasra
# Processing Record 3 of Set 9 | kevsala
# Processing Record 4 of Set 9 | inta
# Processing Record 5 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 6 of Set 9 | townsville
# Processing Record 7 of Set 9 | luang prabang
# Processing Record 8 of Set 9 | road town
# Processing Record 9 of Set 9 | darovskoy
# Processing Record 10 of Set 9 | ulladulla
# Processing Record 11 of Set 9 | flinders
# Processing Record 12 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 9 | mount isa
# Processing Record 14 of Set 9 | bodden town
# Processing Record 15 of Set 9 | athabasca
# Processing Record 16 of Set 9 | sahrak
# City not found. Skipping...
# Processing Record 17 of Set 9 | mikuni
# Processing Record 18 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 19 of Set 9 | baykit
# Processing Record 20 of Set 9 | hithadhoo
# Processing Record 21 of Set 9 | lima
# Processing Record 22 of Set 9 | roald
# Processing Record 23 of Set 9 | takoradi
# Processing Record 24 of Set 9 | gravata
# Processing Record 25 of Set 9 | vice
# Processing Record 26 of Set 9 | alofi
# Processing Record 27 of Set 9 | chkalovsk
# Processing Record 28 of Set 9 | marovoay
# Processing Record 29 of Set 9 | robertsport
# Processing Record 30 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 9 | tura
# Processing Record 32 of Set 9 | lyaskelya
# Processing Record 33 of Set 9 | natal
# Processing Record 34 of Set 9 | celestun
# Processing Record 35 of Set 9 | sinnamary
# Processing Record 36 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 38 of Set 9 | wentzville
# Processing Record 39 of Set 9 | hit
# Processing Record 40 of Set 9 | huejuquilla el alto
# Processing Record 41 of Set 9 | ancud
# Processing Record 42 of Set 9 | isangel
# Processing Record 43 of Set 9 | baboua
# City not found. Skipping...
# Processing Record 44 of Set 9 | garden city
# Processing Record 45 of Set 9 | broken hill
# Processing Record 46 of Set 9 | saint paul
# Processing Record 47 of Set 9 | aksarayskiy
# Processing Record 48 of Set 9 | ankpa
# Processing Record 49 of Set 9 | beaufort
# Processing Record 50 of Set 9 | damara
# Processing Record 1 of Set 10 | moree
# Processing Record 2 of Set 10 | san andres
# Processing Record 3 of Set 10 | christchurch
# Processing Record 4 of Set 10 | manjeshwar
# Processing Record 5 of Set 10 | mitsamiouli
# Processing Record 6 of Set 10 | kushiro
# Processing Record 7 of Set 10 | upington
# Processing Record 8 of Set 10 | nouakchott
# Processing Record 9 of Set 10 | waitati
# Processing Record 10 of Set 10 | jumla
# Processing Record 11 of Set 10 | chapada dos guimaraes
# Processing Record 12 of Set 10 | labuhan
# Processing Record 13 of Set 10 | kaeng khlo
# City not found. Skipping...
# Processing Record 14 of Set 10 | hambantota
# Processing Record 15 of Set 10 | sayyan
# Processing Record 16 of Set 10 | jega
# Processing Record 17 of Set 10 | ozernovskiy
# Processing Record 18 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 19 of Set 10 | tiznit
# Processing Record 20 of Set 10 | srednekolymsk
# Processing Record 21 of Set 10 | nanortalik
# Processing Record 22 of Set 10 | dalvik
# Processing Record 23 of Set 10 | iqaluit
# Processing Record 24 of Set 10 | salgueiro
# Processing Record 25 of Set 10 | udachnyy
# Processing Record 26 of Set 10 | port keats
# Processing Record 27 of Set 10 | padang
# Processing Record 28 of Set 10 | half moon bay
# Processing Record 29 of Set 10 | fort nelson
# Processing Record 30 of Set 10 | isla mujeres
# Processing Record 31 of Set 10 | manicore
# Processing Record 32 of Set 10 | sabha
# Processing Record 33 of Set 10 | victor harbor
# Processing Record 34 of Set 10 | kyakhta
# Processing Record 35 of Set 10 | miraflores
# Processing Record 36 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 10 | auki
# Processing Record 38 of Set 10 | olafsvik
# Processing Record 39 of Set 10 | sirjan
# Processing Record 40 of Set 10 | inirida
# Processing Record 41 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 42 of Set 10 | rorvik
# Processing Record 43 of Set 10 | terney
# Processing Record 44 of Set 10 | alekseyevsk
# Processing Record 45 of Set 10 | clarence town
# Processing Record 46 of Set 10 | fecamp
# Processing Record 47 of Set 10 | vestmannaeyjar
# Processing Record 48 of Set 10 | darhan
# Processing Record 49 of Set 10 | cayenne
# Processing Record 50 of Set 10 | adre
# Processing Record 1 of Set 11 | severnoye
# Processing Record 2 of Set 11 | taboga
# Processing Record 3 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 11 | moratuwa
# Processing Record 5 of Set 11 | sioux lookout
# Processing Record 6 of Set 11 | cabot
# Processing Record 7 of Set 11 | puerto suarez
# Processing Record 8 of Set 11 | mavrovi anovi
# Processing Record 9 of Set 11 | port moresby
# Processing Record 10 of Set 11 | kiunga
# Processing Record 11 of Set 11 | carbondale
# Processing Record 12 of Set 11 | prescott
# Processing Record 13 of Set 11 | constitucion
# Processing Record 14 of Set 11 | mayskiy
# Processing Record 15 of Set 11 | kahului
# Processing Record 16 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 11 | namibe
# Processing Record 18 of Set 11 | kralendijk
# Processing Record 19 of Set 11 | dubai
# Processing Record 20 of Set 11 | guanica
# Processing Record 21 of Set 11 | namtsy
# Processing Record 22 of Set 11 | talnakh
# Processing Record 23 of Set 11 | goderich
# Processing Record 24 of Set 11 | matara
# Processing Record 25 of Set 11 | yarega
# Processing Record 26 of Set 11 | ust-nera
# Processing Record 27 of Set 11 | doha
# Processing Record 28 of Set 11 | marzuq
# Processing Record 29 of Set 11 | merville
# Processing Record 30 of Set 11 | tarauaca
# Processing Record 31 of Set 11 | kaitangata
# Processing Record 32 of Set 11 | chapais
# Processing Record 33 of Set 11 | klyuchi
# Processing Record 34 of Set 11 | vanavara
# Processing Record 35 of Set 11 | whitehorse
# Processing Record 36 of Set 11 | maldonado
# Processing Record 37 of Set 11 | mwinilunga
# Processing Record 38 of Set 11 | burnie
# Processing Record 39 of Set 11 | dolinsk
# Processing Record 40 of Set 11 | tarascon
# Processing Record 41 of Set 11 | malinyi
# Processing Record 42 of Set 11 | oranjemund
# Processing Record 43 of Set 11 | maniitsoq
# Processing Record 44 of Set 11 | gladstone
# Processing Record 45 of Set 11 | paamiut
# Processing Record 46 of Set 11 | severo-kurilsk
# Processing Record 47 of Set 11 | sobolevo
# Processing Record 48 of Set 11 | kazanskoye
# Processing Record 49 of Set 11 | kangasala
# Processing Record 50 of Set 11 | samarai
# Processing Record 1 of Set 12 | roma
# Processing Record 2 of Set 12 | morehead
# Processing Record 3 of Set 12 | prince rupert
# Processing Record 4 of Set 12 | diban
# Processing Record 5 of Set 12 | hvide sande
# Processing Record 6 of Set 12 | zaterechnyy
# Processing Record 7 of Set 12 | pasighat
# Processing Record 8 of Set 12 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 9 of Set 12 | flin flon
# Processing Record 10 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 11 of Set 12 | miram shah
# Processing Record 12 of Set 12 | channel-port aux basques
# Processing Record 13 of Set 12 | gafargaon
# Processing Record 14 of Set 12 | meybod
# Processing Record 15 of Set 12 | kenora
# Processing Record 16 of Set 12 | sungairaya
# Processing Record 17 of Set 12 | naples
# Processing Record 18 of Set 12 | saquena
# Processing Record 19 of Set 12 | meghraj
# Processing Record 20 of Set 12 | ochamchira
# Processing Record 21 of Set 12 | walvis bay
# Processing Record 22 of Set 12 | nacozari
# Processing Record 23 of Set 12 | mount gambier
# Processing Record 24 of Set 12 | kenai
# Processing Record 25 of Set 12 | knoxville
# Processing Record 26 of Set 12 | juegang
# Processing Record 27 of Set 12 | mezen
# Processing Record 28 of Set 12 | marfino
# Processing Record 29 of Set 12 | mandalgovi
# Processing Record 30 of Set 12 | ikalamavony
# Processing Record 31 of Set 12 | chuy
# Processing Record 32 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 33 of Set 12 | iquitos
# Processing Record 34 of Set 12 | bollnas
# Processing Record 35 of Set 12 | lamar
# Processing Record 36 of Set 12 | mwense
# Processing Record 37 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 38 of Set 12 | gigmoto
# Processing Record 39 of Set 12 | svetlaya
# Processing Record 40 of Set 12 | tiruvottiyur
# City not found. Skipping...
# Processing Record 41 of Set 12 | tabou
# Processing Record 42 of Set 12 | qena
# Processing Record 43 of Set 12 | kitimat
# Processing Record 44 of Set 12 | beruwala
# Processing Record 45 of Set 12 | constantine
# Processing Record 46 of Set 12 | barra patuca
# Processing Record 47 of Set 12 | key west
# Processing Record 48 of Set 12 | avera
# Processing Record 49 of Set 12 | los llanos de aridane
# Processing Record 50 of Set 12 | baykalovo
# Processing Record 1 of Set 13 | amahai
# Processing Record 2 of Set 13 | poum
# Processing Record 3 of Set 13 | kambove
# Processing Record 4 of Set 13 | smithers
# Processing Record 5 of Set 13 | palm coast
# Processing Record 6 of Set 13 | suwalki
# Processing Record 7 of Set 13 | port hedland
# Processing Record 8 of Set 13 | benghazi
# Processing Record 9 of Set 13 | wamba
# Processing Record 10 of Set 13 | kerchevskiy
# Processing Record 11 of Set 13 | isla vista
# Processing Record 12 of Set 13 | ebano
# City not found. Skipping...
# Processing Record 13 of Set 13 | den helder
# Processing Record 14 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 13 | tashla
# Processing Record 16 of Set 13 | dokri
# Processing Record 17 of Set 13 | sackville
# Processing Record 18 of Set 13 | humberto de campos
# Processing Record 19 of Set 13 | izmaylovo
# Processing Record 20 of Set 13 | richards bay
# Processing Record 21 of Set 13 | teberda
# Processing Record 22 of Set 13 | lumeje
# Processing Record 23 of Set 13 | calvia
# Processing Record 24 of Set 13 | nador
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Musiri      IN  10.9333   78.4500     75.20        83          20
# 1  Ciudad Dario      NI  12.7314  -86.1240     69.80        73          75
# 2       Quixada      BR  -4.9714  -39.0153     95.29        32          55
# 3          Vila      PT  42.0304   -8.1588     53.01        94          92
# 4      Khatanga      RU  71.9667  102.5000    -44.18        79          48
# 5        Kargil      IN  34.5667   76.1000      0.10        74         100
# 6         Bluff      NZ -46.6000  168.3333     55.26        82          96
# 7   New Norfolk      AU -42.7826  147.0587     55.99        70          45
# 8   Tuktoyaktuk      CA  69.4541 -133.0374    -31.00        75          75
# 9      Tasiilaq      GL  65.6145  -37.6368     14.00        57          75
#
#    Wind Speed Current Description
# 0        6.91                mist
# 1       18.41       broken clouds
# 2        7.38       moderate rain
# 3       18.01     overcast clouds
# 4        5.23    scattered clouds
# 5        1.79                snow
# 6        6.49     overcast clouds
# 7        2.06    scattered clouds
# 8        2.30       broken clouds
# 9        4.61       broken clouds

# %%
len(city_data)
# Out:
# 573

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
